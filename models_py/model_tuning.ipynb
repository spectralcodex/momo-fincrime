# %%
# Logistic regression
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('../data/Social_Network_Ads.csv')
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
print(X_train)
# Out:
# [[ 0.58164944 -0.88670699]
#  [-0.60673761  1.46173768]
#  [-0.01254409 -0.5677824 ]
#  [-0.60673761  1.89663484]
#  [ 1.37390747 -1.40858358]
#  [ 1.47293972  0.99784738]
#  [ 0.08648817 -0.79972756]
#  [-0.01254409 -0.24885782]
#  [-0.21060859 -0.5677824 ]
#  [-0.21060859 -0.19087153]
#  [-0.30964085 -1.29261101]
#  [-0.30964085 -0.5677824 ]
#  [ 0.38358493  0.09905991]
#  [ 0.8787462  -0.59677555]
#  [ 2.06713324 -1.17663843]
#  [ 1.07681071 -0.13288524]
#  [ 0.68068169  1.78066227]
#  [-0.70576986  0.56295021]
#  [ 0.77971394  0.35999821]
#  [ 0.8787462  -0.53878926]
#  [-1.20093113 -1.58254245]
#  [ 2.1661655   0.93986109]
#  [-0.01254409  1.22979253]
#  [ 0.18552042  1.08482681]
#  [ 0.38358493 -0.48080297]
#  [-0.30964085 -0.30684411]
#  [ 0.97777845 -0.8287207 ]
#  [ 0.97777845  1.8676417 ]
#  [-0.01254409  1.25878567]
#  [-0.90383437  2.27354572]
#  [-1.20093113 -1.58254245]
#  [ 2.1661655  -0.79972756]
#  [-1.39899564 -1.46656987]
#  [ 0.38358493  2.30253886]
# ...

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state = 0)
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler
from imblearn.pipeline import Pipeline
from collections import Counter

# Create a simple banking dataset
np.random.seed(42)
n_samples = 10000

# Generate features
age = np.random.randint(18, 70, n_samples)
income = np.random.randint(20000, 200000, n_samples)
loan_amount = np.random.randint(1000, 50000, n_samples)
credit_score = np.random.randint(300, 850, n_samples)

# Generate target (loan default)
# Let's assume 10% default rate
default = np.random.choice([0, 1], n_samples, p=[0.9, 0.1])

# Create DataFrame
df = pd.DataFrame({
    'age': age,
    'income': income,
    'loan_amount': loan_amount,
    'credit_score': credit_score,
    'default': default
})

# Separate features and target
X = df.drop('default', axis=1)
y = df['default']

# Print original class distribution
print("Original class distribution:", Counter(y))

# Scale the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Define sampling strategy
# We'll aim for a 50-50 split between default and non-default
n_samples_desired = 0.5
sampling_strategy = {0: 0.4, 1: 1}

# Create a pipeline with both over and under sampling
pipeline = Pipeline([
    ('over', RandomOverSampler(sampling_strategy=0.4, random_state=42)),
    ('under', RandomUnderSampler(sampling_strategy=1, random_state=42))
])
# Out:
# Original class distribution: Counter({0: 8988, 1: 1012})

# %%
# Fit and transform the data
X_resampled, y_resampled = pipeline.fit_resample(X, y)

# Print new class distribution
print("Resampled class distribution:", Counter(y_resampled))

# Print shape of original and resampled data
print("Original shape:", X_scaled.shape)
print("Resampled shape:", X_resampled.shape)

# Convert resampled data back to DataFrame for easier viewing
X_resampled_df = pd.DataFrame(X_resampled, columns=X.columns)
X_resampled_df['default'] = y_resampled

print("\nFirst few rows of resampled data:")
print(X_resampled_df.head())
# Out:
# Resampled class distribution: Counter({0: 3595, 1: 3595})
# Original shape: (10000, 4)
# Resampled shape: (7190, 4)
#
# First few rows of resampled data:
#       age  income  loan_amount  credit_score  default
# 8863   62   29623        24184           412        0
# 186    37   78759        48287           818        0
# 965    47   24922        12140           656        0
# 2925   24   48546         9265           724        0
# 819    50  185542         7066           569        0

# %%
# Convert resampled data back to DataFrame for easier viewing
X_resampled_df = pd.DataFrame(X_resampled, columns=X.columns)
X_resampled_df['isFraud'] = y_resampled
X_resampled_df.sample(frac = 1)
resampled_df = X_resampled_df.reset_index()

# %%
# example of combining random oversampling and undersampling for imbalanced data
from collections import Counter
from sklearn.datasets import make_classification
from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler
# define dataset
X, y = make_classification(n_samples=10000, weights=[0.99], flip_y=0)
# summarize class distribution
print(Counter(y))
# define oversampling strategy
over = RandomOverSampler(sampling_strategy=0.1)
# fit and apply the transform
X, y = over.fit_resample(X, y)
# summarize class distribution
print(Counter(y))
# define undersampling strategy
under = RandomUnderSampler(sampling_strategy=0.5)
# fit and apply the transform
X, y = under.fit_resample(X, y)
# summarize class distribution
print(Counter(y))
# Out:
# Counter({0: 9900, 1: 100})
# Counter({0: 9900, 1: 990})
# Counter({0: 1980, 1: 990})
